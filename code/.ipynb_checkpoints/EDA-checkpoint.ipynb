# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
# onehot encoded dataset
df = pd.read_csv(r'E:\AWS Machine learning\full pipeline project\s3\processing_jobs\processed_data\dataset.csv')
df.head(10)
# Out:
#    fraud  num_vehicles_involved  num_injuries  num_witnesses  \
# 0      0                      2             0              0
# 1      0                      3             4              0
# 2      0                      2             0              1
# 3      0                      2             0              0
# 4      0                      2             1              0
# 5      0                      3             1              2
# 6      0                      1             0              0
# 7      0                      1             0              0
# 8      0                      3             4              1
# 9      0                      2             0              1
#
#    police_report_available  injury_claim  vehicle_claim  total_claim_amount  \
# 0                      0.0         71600    8913.668763        80513.668763
# 1                      1.0          6400   19746.724395        26146.724395
# ...

# %%
df.dtypes
# Out:
# fraud                                int64
# num_vehicles_involved                int64
# num_injuries                         int64
# num_witnesses                        int64
# police_report_available            float64
# injury_claim                         int64
# vehicle_claim                      float64
# total_claim_amount                 float64
# incident_month                       int64
# incident_day                         int64
# incident_dow                         int64
# incident_hour                        int64
# customer_age                         int64
# months_as_customer                   int64
# num_claims_past_year                 int64
# num_insurers_past_5_years            int64
# policy_deductable                    int64
# policy_annual_premium                int64
# policy_liability                   float64
# customer_education                 float64
# auto_year                            int64
# driver_relationship_child            int64
# ...

# %%
df.shape
# Out:
# (5000, 49)

# %%
# dataset summary
df.describe()
# Out:
#              fraud  num_vehicles_involved  num_injuries  num_witnesses  \
# count  5000.000000            5000.000000   5000.000000    5000.000000
# mean      0.032800               2.109600      0.561800       0.864600
# std       0.178131               0.842217      1.003186       1.110186
# min       0.000000               1.000000      0.000000       0.000000
# 25%       0.000000               2.000000      0.000000       0.000000
# 50%       0.000000               2.000000      0.000000       0.000000
# 75%       0.000000               3.000000      1.000000       2.000000
# max       1.000000               6.000000      4.000000       5.000000
#
#        police_report_available   injury_claim  vehicle_claim  \
# count              5000.000000    5000.000000    5000.000000
# mean                  0.421600   24000.300000   17267.355952
# std                   0.493865   30834.816411   10108.375668
# min                   0.000000     300.000000    1000.000000
# ...

# %%
# checking if the data contains any NULL values

df.isnull().sum()
# Out:
# fraud                              0
# num_vehicles_involved              0
# num_injuries                       0
# num_witnesses                      0
# police_report_available            0
# injury_claim                       0
# vehicle_claim                      0
# total_claim_amount                 0
# incident_month                     0
# incident_day                       0
# incident_dow                       0
# incident_hour                      0
# customer_age                       0
# months_as_customer                 0
# num_claims_past_year               0
# num_insurers_past_5_years          0
# policy_deductable                  0
# policy_annual_premium              0
# policy_liability                   0
# customer_education                 0
# auto_year                          0
# driver_relationship_child          0
# driver_relationship_other          0
# driver_relationship_self           0
# driver_relationship_spouse         0
# ...

# %%
# checking distribution of fraud coulumn
# Just 3.28% of Data has fraud observations, 96.72% observations are not fraud
df['fraud'].value_counts()
# Out:
# 0    4836
# 1     164
# Name: fraud, dtype: int64

# %%
# distribution of fraud cases by customer age
# We can see customer ages between 20 - 30 has more fraud cases 
fraud_distribution = df.groupby('customer_age')['fraud'].sum()
plt.figure(figsize=(10, 6))
plt.bar(fraud_distribution.index, fraud_distribution.values)
plt.xlabel('Customer Age')
plt.ylabel('Number of Fraud Cases')
plt.title('Distribution of Fraud Cases by Customer Age')
plt.grid(True)
plt.show()

# %%
# distribution of fraud cases by Idaho state

filtered_df = df[df['policy_state_id'] == 1]

fraud_distribution = filtered_df.groupby('policy_state_id')['fraud'].sum()

print("Total size of observations of Idaho state=",len(filtered_df))
print("Number of frauds by Idaho state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of Idaho state= 135
# Number of frauds by Idaho state= 4
# Percentage of fraud in claims made= 2.96 %

# %%
# distribution of fraud cases by arizona state

filtered_df = df[df['policy_state_az'] == 1]

fraud_distribution = filtered_df.groupby('policy_state_az')['fraud'].sum()

print("Total size of observations of arizona state=",len(filtered_df))
print("Number of frauds by Arizona state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of arizona state= 539
# Number of frauds by Arizona state= 17
# Percentage of fraud in claims made= 3.15 %

# %%
# distribution of fraud cases by nevada state

filtered_df = df[df['policy_state_nv'] == 1]

fraud_distribution = filtered_df.groupby('policy_state_nv')['fraud'].sum()
print("Total size of observations of Nevada state=",len(filtered_df))
print("Number of frauds by Nevada state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of Nevada state= 222
# Number of frauds by Nevada state= 6
# Percentage of fraud in claims made= 2.7 %

# %%
# distribution of fraud cases by Oregon state

filtered_df = df[df['policy_state_or'] == 1]

print("Total size of observations of Oregon state=",len(filtered_df))
fraud_distribution = filtered_df.groupby('policy_state_or')['fraud'].sum()
print("Number of frauds by Oregon state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of Oregon state= 363
# Number of frauds by Oregon state= 12
# Percentage of fraud in claims made= 3.31 %

# %%
# distribution of fraud cases by washington state

filtered_df = df[df['policy_state_wa'] == 1]

fraud_distribution = filtered_df.groupby('policy_state_wa')['fraud'].sum()
print("Total size of observations of Washington state=",len(filtered_df))
print("Number of frauds by Washington state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of Washington state= 607
# Number of frauds by Washington state= 19
# Percentage of fraud in claims made= 3.13 %

# %%
# distribution of fraud cases by California state

filtered_df = df[df['policy_state_ca'] == 1]

fraud_distribution = filtered_df.groupby('policy_state_ca')['fraud'].sum()

print("Total size of observations of California state=",len(filtered_df))
print("Number of frauds by California state=",fraud_distribution.loc[1])
print("Percentage of fraud in claims made=",round((fraud_distribution.loc[1]/len(filtered_df))*100,2),"%")
# Out:
# Total size of observations of California state= 3134
# Number of frauds by California state= 106
# Percentage of fraud in claims made= 3.38 %

# %%
## Among above observations made Nevada state has comparitively less fraud cases.California has the highest fraud cases.

# %%
categorical_columns = ['driver_relationship', 'incident_type', 'collision_type','incident_severity','authorities_contacted','policy_state','customer_gender']  # Replace with your actual column names

# Read the CSV file and explicitly set the data types of categorical columns as 'category' or elese pandas treat each cataegory as a new column
df_raw = pd.read_csv(r'E:\AWS Machine learning\full pipeline project\original data\FOR_EDA.csv', dtype={col: 'category' for col in categorical_columns})
df_raw.dtypes
# Out:
# fraud                           int64
# driver_relationship          category
# incident_type                category
# collision_type               category
# incident_severity            category
# authorities_contacted        category
# num_vehicles_involved           int64
# num_injuries                    int64
# num_witnesses                   int64
# police_report_available       float64
# injury_claim                    int64
# vehicle_claim                 float64
# total_claim_amount            float64
# incident_month                  int64
# incident_day                    int64
# incident_dow                    int64
# incident_hour                   int64
# customer_age                    int64
# months_as_customer              int64
# num_claims_past_year            int64
# num_insurers_past_5_years       int64
# policy_state                 category
# policy_deductable               int64
# policy_annual_premium           int64
# policy_liability              float64
# ...

# %%
# Number of observations and features
df_raw.shape
# Out:
# (5000, 28)

# %%
# This clearly shows California has hoghest fraud cases
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('policy_state').fraud.count().plot.bar(ylim=0)
ax.set_ylabel('fraud')
plt.show()

# %%
# Total claim amounts in each month of the year
# January,October and November has highest claims compared to other months
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(18,6))
ax = df_raw.groupby('incident_month').total_claim_amount.count().plot.bar(ylim=0)
ax.set_ylabel('Claim amount ($)')
plt.show()

# %%
# Vehicles claimed to be met with collision is the most fraud cases and least being the theft cases.

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('incident_type').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
# Incident severity category belonging to Minority had most fraud cases, second being Major and least being Totaled. 
plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('incident_severity').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
# Insurance claims with driver relationship as self has the highest fradulent cases.

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('driver_relationship').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
#Fraud cases by insured relationship 

import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')


fraud_counts_relationship = df_raw['fraud'].groupby(df_raw['driver_relationship']).sum()

# Calculate the percentage of each insured relationship
total_fraud_cases_relationship = fraud_counts_relationship.sum()
percentages_relationship = [(count / total_fraud_cases_relationship) * 100 for count in fraud_counts_relationship]

# Create a pie chart
fig, ax = plt.subplots(figsize=(10, 6))
colors_relationship = ['#008fd5', '#fc4f30', '#e5ae38', 'purple', 'lightblue'] 
wedges_relationship, _ = ax.pie(fraud_counts_relationship, labels=None, autopct=None, startangle=90, colors=colors_relationship)
ax.set_aspect('equal')  # Equal aspect ratio ensures that the pie chart is circular
ax.set_title('Fraud Cases by Insured Relationship', fontsize=16)

# Create the legend
ax.legend(wedges_relationship, [f'{label} ({percentage:.1f}%)' for label, percentage in zip(fraud_counts_relationship.index, percentages_relationship)], 
          title='Insured Relationship', fontsize=12, loc='best')

plt.show()

# %%
# Authorities contacted when fraud claims were made is Police, which is quite surprising. As this should not be the fraud case.

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('authorities_contacted').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
# with 0 being the number of witness when farud cases were filled is maximum which is as expected. 

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('num_witnesses').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
# Number of fradulent cases are considerably high between 8am to 4pm. Least at 9pm-3am. 

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('incident_hour').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=20, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
#People with Bachelors degree do a maximum fradulent claims and people with education below high school do less fraud claims.

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('customer_education').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
# Both male and female approximately claim equal fraud claims

plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(10,6))
ax = df_raw.groupby('customer_gender').fraud.count().plot.bar(ylim=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=25, ha="right")
ax.set_ylabel('Fraud reported')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')


fraud_counts = df_raw['fraud'].groupby(df_raw['customer_gender']).sum()

# Calculate the percentage of each gender
total_fraud_cases = fraud_counts.sum()
percentages = [(count / total_fraud_cases) * 100 for count in fraud_counts]


fig, ax = plt.subplots(figsize=(10, 7))
colors = ['#008fd5', '#fc4f30', '#e5ae38', 'purple'] 
wedges, _ = ax.pie(fraud_counts, labels=None, autopct=None, startangle=90, colors=colors)
ax.set_aspect('equal')  # Equal aspect ratio ensures that the pie chart is circular


ax.set_title('Fraud Cases by Customer Gender', fontsize=16)

# legend with percentages
ax.legend(wedges, [f'{label} ({percentage:.1f}%)' for label, percentage in zip(fraud_counts.index, percentages)], 
          title='Customer Gender', fontsize=12, loc='best')

plt.show()

# %%
# This describes that Annual Policy with highest Premium gets more fraud claims. 
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')


fraud_counts = df_raw['fraud'].groupby(df_raw['policy_annual_premium']).sum()

# Calculate the percentage of each gender
total_fraud_cases = fraud_counts.sum()
percentages = [(count / total_fraud_cases) * 100 for count in fraud_counts]


fig, ax = plt.subplots(figsize=(10, 7))
colors = ['#008fd5', '#fc4f30', '#e5ae38', 'purple'] 
wedges, _ = ax.pie(fraud_counts, labels=None, autopct=None, startangle=90, colors=colors)
ax.set_aspect('equal')  # Equal aspect ratio ensures that the pie chart is circular


ax.set_title('Fraud Cases by policy_annual_premium', fontsize=16)

# legend with percentages
ax.legend(wedges, [f'{label} ({percentage:.1f}%)' for label, percentage in zip(fraud_counts.index, percentages)], 
          title='policy_annual_premium', fontsize=12, loc='best')

plt.show()

# %%
# Vehicles with make year starting from 2014 has increasing trend of false claims, with vehicles made in 2017-2018 has highest fraud claims.

import pandas as pd
import matplotlib.pyplot as plt



plt.style.use('fivethirtyeight')
fig = plt.figure(figsize=(15, 10))
ax = df_raw.groupby('auto_year').fraud.count().plot.line(ylim=0)


custom_ticks = list(range(2001, 2021))
ax.set_xticks(custom_ticks)


custom_tick_labels = [str(year) for year in custom_ticks]
ax.set_xticklabels(custom_tick_labels, rotation=30, ha="right")

ax.set_ylabel('Fraud reported')
plt.show()

# %%
# ## Data prep for EDA (without one-hot encoding)

# df_claims = pd.read_csv(r'E:\AWS Machine learning\full pipeline project\original data\local_claims.csv')
    

# df_customers = pd.read_csv(r'E:\AWS Machine learning\full pipeline project\original data\local_customers.csv')


# # Format column names
# df_claims = df_claims.rename({c : c.lower().strip().replace(' ', '_') for c in df_claims.columns}, axis = 1)
# df_customers = df_customers.rename({c : c.lower().strip().replace(' ', '_') for c in df_customers.columns}, axis = 1)


# # Join datasets
# df_data = df_claims.merge(df_customers, on = 'policy_id', how = 'left')

# # Drop selected columns not required for model building
# df_data = df_data.drop(['customer_zip'], axis = 1)

# # Select Ordinal columns
# ordinal_cols = ["police_report_available", "policy_liability", "customer_education"]

# # Select categorical columns and filling with na
# cat_cols_all = list(df_data.select_dtypes('object').columns)
# cat_cols = [c for c in cat_cols_all if c not in ordinal_cols]
# df_data[cat_cols] = df_data[cat_cols].fillna('na')


# # Ordinal encoding
# mapping = {
#            "Yes": "1",
#            "No": "0" 
#           }
# df_data['police_report_available'] = df_data['police_report_available'].map(mapping)
# df_data['police_report_available'] = df_data['police_report_available'].astype(float)

# mapping = {
#            "15/30": "0",
#            "25/50": "1", 
#            "30/60": "2",
#            "100/200": "3"
#           }

# df_data['policy_liability'] = df_data['policy_liability'].map(mapping)
# df_data['policy_liability'] = df_data['policy_liability'].astype(float)

# # mapping = {
# #            "Below High School": "0",
# #            "High School": "1", 
# #            "Associate": "2",
# #            "Bachelor": "3",
# #            "Advanced Degree": "4"
# #           }

# # df_data['customer_education'] = df_data['customer_education'].map(mapping)
# # df_data['customer_education'] = df_data['customer_education'].astype(float)

# df_processed = df_data.copy()
# df_processed.columns = [c.lower() for c in df_data.columns]
# df_processed = df_processed.drop(["policy_id"], axis=1)



# y = df_processed['fraud']
# X = df_processed.drop(['fraud'], axis = 1)

# dataset_df = pd.concat([y, X], axis = 1)
# dataset_df.to_csv('FOR_EDA.csv', index=False)
